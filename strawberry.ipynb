# %%
import cv2

# %%
image = cv2.imread("C:\\Users\\Dell Latitude 7490\\Pictures\\strawberry.jpg")

cv2.imshow("strawberry", image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import matplotlib.pyplot as plt

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

half = cv2.resize(image_rgb, (0, 0), fx = 0.05, fy = 0.05)
bigger = cv2.resize(image_rgb, (1050, 1610))

stretch_near = cv2.resize(image_rgb, (1000, 100),
            interpolation = cv2.INTER_NEAREST)

Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image_rgb, half, bigger, stretch_near]
count = 4

for i in range(count):
    plt.subplot(2, 3, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
    plt.axis('off')

plt.show()

# %%
from matplotlib import pyplot as plt

image = cv2.imread("C:\\Users\\Dell Latitude 7490\\Pictures\\strawberry.jpg")

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)



Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image_rgb, half, bigger, stretch_near]
count = 4

# %%
print("Image shape:", image.shape)
# Out:
# Image shape: (350, 642, 3)

# %%
import matplotlib.pyplot as plt
import cv2


image = cv2.imread("C:\\Users\\Dell Latitude 7490\\Pictures\\strawberry.jpg")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(641.5), np.float64(349.5), np.float64(-0.5))

# %%
import numpy as np

image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_red = np.array([0, 120, 70])
upper_red = np.array([10, 255, 255])

mask = cv2.inRange(image_hsv, lower_red, upper_red)

result = cv2.bitwise_and(image, image, mask=mask)

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(641.5), np.float64(349.5), np.float64(-0.5))

# %%
lower_white = np.array([0, 0, 180])   
upper_white = np.array([179, 70, 255]) 

mask = cv2.inRange(image_hsv, lower_white, upper_white)

result = cv2.bitwise_and(image, image, mask=mask)

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(641.5), np.float64(349.5), np.float64(-0.5))

# %%
lower_green = np.array([36, 25, 25])  
upper_green = np.array([86, 255, 255]) 

mask = cv2.inRange(image_hsv, lower_green, upper_green)

result = cv2.bitwise_and(image, image, mask=mask)

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(641.5), np.float64(349.5), np.float64(-0.5))

# %%
B, G, R = cv2.split(image)

fig, axs = plt.subplots(1, 3, figsize=(8, 8))
axs[0].imshow(R, cmap='gray')
axs[0].set_title('Red Channel')
axs[0].axis('off')
axs[1].imshow(G, cmap='gray')
axs[1].set_title('Green Channel')
axs[1].axis('off')
axs[2].imshow(B, cmap='gray')
axs[2].set_title('Blue Channel')
axs[2].axis('off')
plt.show()
